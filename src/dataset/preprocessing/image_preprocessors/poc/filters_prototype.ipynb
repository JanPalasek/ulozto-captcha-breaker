# %%
import cv2
import matplotlib.pyplot as plt
from dataset.preprocessing.image_preprocessors.convert_to_grayscale_preprocessor import ConvertToGrayscalePreprocessor

src_img_path = "/media/honza/ubuntu_2/root_folder/Documents/Personal/ulozto-captcha-solver/out/data/aabx_ee1e2354-fe20-439c-9d11-ac6afbede168.png"

img = cv2.imread(src_img_path)
plt.imshow(img)

# %%
grayscale = ConvertToGrayscalePreprocessor()
img = grayscale(img)
plt.imshow(img)

# %%
blurred_img = cv2.medianBlur(img, 5)
plt.imshow(blurred_img)
